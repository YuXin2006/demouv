# %%
import pandas as pd

df = pd.read_csv("large_sales_data.csv")
print(df.head())
# Out:
#     order_id            timestamp   pid  user_id  actual_price  quantity  \
# 0  ORD000000  2023-03-26 16:38:00  P003    10041       1380.54         1
# 1  ORD000001  2023-04-02 14:52:00  P002    10396        320.41         1
# 2  ORD000002  2023-09-12 01:18:00  P005    10112       2369.72         1
# 3  ORD000003  2023-06-29 23:38:00  P004    10104        448.62         1
# 4  ORD000004  2023-03-18 13:48:00  P004    10191        415.19         1
#
#   region payment_method
# 0     西南             微信
# 1     华北             微信
# 2     西南            支付宝
# 3     西南            NaN
# 4     华南            支付宝
