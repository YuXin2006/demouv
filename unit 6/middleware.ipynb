# %%
from langchain.agents import create_agent
import os
from dotenv import load_dotenv
load_dotenv()
os.environ["OPEN_API_KEY"]=os.environ["DEEPSEEK_API_KEY"]

# %%
from langchain.agents.middleware import SummarizationMiddleware
from langgraph.checkpoint.memory import InMemorySaver
from langchain_core.messages import HumanMessage, SystemMessage
agent=create_agent(
    model="deepseek-chat",
    checkpointer=InMemorySaver(),
    middleware=[
        SummarizationMiddleware(
            model="deepseek-chat",
            trigger=("messages",6),
            keep=("messages",4)
        )
    ],
)    
config={"configurable":{"thread_id":"test1"}}
question=[
    "三加三等于多少?",
    "今天是星期三明天是星期几？",
    "how are you now?",
    "我想知道更多关于你的情况",
    "珠穆朗玛峰有多高？",
    "中国面积有多大"
]

for q in question:
    response=agent.invoke({"messages":[HumanMessage(content=q)]},config)
    print(f"Messages:{response}")
    print(f"Messages: {len(response['messages'])}")
# Out:
# Messages:{'messages': [HumanMessage(content='三加三等于多少?', additional_kwargs={}, response_metadata={}, id='47bd91a7-299a-4e95-b105-7634aafad6eb'), AIMessage(content='三加三等于六。', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 6, 'prompt_tokens': 10, 'total_tokens': 16, 'completion_tokens_details': None, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 10}, 'model_provider': 'deepseek', 'model_name': 'deepseek-v4-flash', 'system_fingerprint': 'fp_058df29938_prod0820_fp8_kvcache_20260402', 'id': 'c9e756fc-0160-4206-9334-0d0c5131f43c', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019dca1c-1232-7553-9705-c10d4a3ec63c-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 10, 'output_tokens': 6, 'total_tokens': 16, 'input_token_details': {'cache_read': 0}, 'output_token_details': {}})]}
# Messages: 2
# Messages:{'messages': [HumanMessage(content='三加三等于多少?', additional_kwargs={}, response_metadata={}, id='47bd91a7-299a-4e95-b105-7634aafad6eb'), AIMessage(content='三加三等于六。', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 6, 'prompt_tokens': 10, 'total_tokens': 16, 'completion_tokens_details': None, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 10}, 'model_provider': 'deepseek', 'model_name': 'deepseek-v4-flash', 'system_fingerprint': 'fp_058df29938_prod0820_fp8_kvcache_20260402', 'id': 'c9e756fc-0160-4206-9334-0d0c5131f43c', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019dca1c-1232-7553-9705-c10d4a3ec63c-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 10, 'output_tokens': 6, 'total_tokens': 16, 'input_token_details': {'cache_read': 0}, 'output_token_details': {}}), HumanMessage(content='今天是星期三明天是星期几？', additional_kwargs={}, response_metadata={}, id='ef0b9d67-2f66-4ecf-a97d-6406147b3eca'), AIMessage(content='根据常规的星期顺序，今天是星期三，那么明天就是**星期四**。', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 16, 'prompt_tokens': 27, 'total_tokens': 43, 'completion_tokens_details': None, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 27}, 'model_provider': 'deepseek', 'model_name': 'deepseek-v4-flash', 'system_fingerprint': 'fp_058df29938_prod0820_fp8_kvcache_20260402', 'id': 'a81e1c93-9c6e-4c5e-a02e-623da27f6af0', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019dca1c-1564-7922-b38f-fe79e0cc2a56-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 27, 'output_tokens': 16, 'total_tokens': 43, 'input_token_details': {'cache_read': 0}, 'output_token_details': {}})]}
# Messages: 4
# Messages:{'messages': [HumanMessage(content='三加三等于多少?', additional_kwargs={}, response_metadata={}, id='47bd91a7-299a-4e95-b105-7634aafad6eb'), AIMessage(content='三加三等于六。', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 6, 'prompt_tokens': 10, 'total_tokens': 16, 'completion_tokens_details': None, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 10}, 'model_provider': 'deepseek', 'model_name': 'deepseek-v4-flash', 'system_fingerprint': 'fp_058df29938_prod0820_fp8_kvcache_20260402', 'id': 'c9e756fc-0160-4206-9334-0d0c5131f43c', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019dca1c-1232-7553-9705-c10d4a3ec63c-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 10, 'output_tokens': 6, 'total_tokens': 16, 'input_token_details': {'cache_read': 0}, 'output_token_details': {}}), HumanMessage(content='今天是星期三明天是星期几？', additional_kwargs={}, response_metadata={}, id='ef0b9d67-2f66-4ecf-a97d-6406147b3eca'), AIMessage(content='根据常规的星期顺序，今天是星期三，那么明天就是**星期四**。', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 16, 'prompt_tokens': 27, 'total_tokens': 43, 'completion_tokens_details': None, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 27}, 'model_provider': 'deepseek', 'model_name': 'deepseek-v4-flash', 'system_fingerprint': 'fp_058df29938_prod0820_fp8_kvcache_20260402', 'id': 'a81e1c93-9c6e-4c5e-a02e-623da27f6af0', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019dca1c-1564-7922-b38f-fe79e0cc2a56-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 27, 'output_tokens': 16, 'total_tokens': 43, 'input_token_details': {'cache_read': 0}, 'output_token_details': {}}), HumanMessage(content='how are you now?', additional_kwargs={}, response_metadata={}, id='e4a018c3-b0d5-42e1-8d9f-1cb3f4d9ee2a'), AIMessage(content="Thanks for asking! I'm functioning well, though as an AI, I don't have feelings. How are you doing?", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 25, 'prompt_tokens': 52, 'total_tokens': 77, 'completion_tokens_details': None, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 52}, 'model_provider': 'deepseek', 'model_name': 'deepseek-v4-flash', 'system_fingerprint': 'fp_058df29938_prod0820_fp8_kvcache_20260402', 'id': '792522a0-213f-42ff-8a1d-829364609ca3', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019dca1c-1836-75f3-a65b-0afcb0963653-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 52, 'output_tokens': 25, 'total_tokens': 77, 'input_token_details': {'cache_read': 0}, 'output_token_details': {}})]}
# Messages: 6
# Messages:{'messages': [HumanMessage(content='Here is a summary of the conversation to date:\n\n## SESSION INTENT\nUser asked basic arithmetic (3+3) and a day-of-week question (given Wednesday, what is tomorrow). Appears to be simple Q&A.\n\n## SUMMARY\n- 3+3=6\n- Today is Wednesday, so tomorrow is Thursday.\n\n## ARTIFACTS\nNone\n\n## NEXT STEPS\nNone', additional_kwargs={'lc_source': 'summarization'}, response_metadata={}, id='0692e58f-bad5-45dc-9612-9e53635f49e7'), AIMessage(content='根据常规的星期顺序，今天是星期三，那么明天就是**星期四**。', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 16, 'prompt_tokens': 27, 'total_tokens': 43, 'completion_tokens_details': None, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 27}, 'model_provider': 'deepseek', 'model_name': 'deepseek-v4-flash', 'system_fingerprint': 'fp_058df29938_prod0820_fp8_kvcache_20260402', 'id': 'a81e1c93-9c6e-4c5e-a02e-623da27f6af0', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019dca1c-1564-7922-b38f-fe79e0cc2a56-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 27, 'output_tokens': 16, 'total_tokens': 43, 'input_token_details': {'cache_read': 0}, 'output_token_details': {}}), HumanMessage(content='how are you now?', additional_kwargs={}, response_metadata={}, id='e4a018c3-b0d5-42e1-8d9f-1cb3f4d9ee2a'), AIMessage(content="Thanks for asking! I'm functioning well, though as an AI, I don't have feelings. How are you doing?", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 25, 'prompt_tokens': 52, 'total_tokens': 77, 'completion_tokens_details': None, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 52}, 'model_provider': 'deepseek', 'model_name': 'deepseek-v4-flash', 'system_fingerprint': 'fp_058df29938_prod0820_fp8_kvcache_20260402', 'id': '792522a0-213f-42ff-8a1d-829364609ca3', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019dca1c-1836-75f3-a65b-0afcb0963653-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 52, 'output_tokens': 25, 'total_tokens': 77, 'input_token_details': {'cache_read': 0}, 'output_token_details': {}}), HumanMessage(content='我想知道更多关于你的情况', additional_kwargs={}, response_metadata={}, id='2c3741f3-dafa-412c-ad13-a3119bd625c5'), AIMessage(content='感谢你的关心！作为一个AI助手，我没有情感、意识或生理状态，所以不存在“心情好”或“累”这类感受。但我一直处于待命状态，随时准备为你提供信息、解答问题或协助完成任务。\n\n如果你对我的技术原理、能力范围或训练方式感兴趣，我可以为你详细介绍。例如：\n\n- 我是基于大规模语言模型构建的，可以处理文本理解、生成、翻译、总结等任务。\n- 知识截止于2025年5月，只能提供在此之前的公开信息（实时信息需联网搜索）。\n- 不支持图像、视频识别（但可以读取上传文件中的文字）。\n- 对话内容匿名，不会保留个人隐私。\n\n你具体想了解哪个方面？比如：我是如何被训练出来的？我能帮你做什么？或者我有哪些局限性？都可以问我！😊', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 169, 'prompt_tokens': 146, 'total_tokens': 315, 'completion_tokens_details': None, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 146}, 'model_provider': 'deepseek', 'model_name': 'deepseek-v4-flash', 'system_fingerprint': 'fp_058df29938_prod0820_fp8_kvcache_20260402', 'id': '3883e6a4-ab7c-4620-94db-237352b1b3a6', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019dca1c-230a-7970-81dd-bf815275a841-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 146, 'output_tokens': 169, 'total_tokens': 315, 'input_token_details': {'cache_read': 0}, 'output_token_details': {}})]}
# Messages: 6
# Messages:{'messages': [HumanMessage(content='Here is a summary of the conversation to date:\n\n## SESSION INTENT\nSimple Q&A session covering basic arithmetic and day-of-week questions.\n\n## SUMMARY\n- User asked "3+3" which equals 6.\n- User asked "If today is Wednesday, what is tomorrow?" The assistant confirmed tomorrow is Thursday.\n- User then asked "how are you now?" — this is a new open question about the assistant\'s current state.\n\n## ARTIFACTS\nNone\n\n## NEXT STEPS\nRespond to the user\'s latest question about how the assistant is now.', additional_kwargs={'lc_source': 'summarization'}, response_metadata={}, id='a8a083c2-2464-46b3-9be6-755625885eba'), AIMessage(content="Thanks for asking! I'm functioning well, though as an AI, I don't have feelings. How are you doing?", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 25, 'prompt_tokens': 52, 'total_tokens': 77, 'completion_tokens_details': None, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 52}, 'model_provider': 'deepseek', 'model_name': 'deepseek-v4-flash', 'system_fingerprint': 'fp_058df29938_prod0820_fp8_kvcache_20260402', 'id': '792522a0-213f-42ff-8a1d-829364609ca3', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019dca1c-1836-75f3-a65b-0afcb0963653-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 52, 'output_tokens': 25, 'total_tokens': 77, 'input_token_details': {'cache_read': 0}, 'output_token_details': {}}), HumanMessage(content='我想知道更多关于你的情况', additional_kwargs={}, response_metadata={}, id='2c3741f3-dafa-412c-ad13-a3119bd625c5'), AIMessage(content='感谢你的关心！作为一个AI助手，我没有情感、意识或生理状态，所以不存在“心情好”或“累”这类感受。但我一直处于待命状态，随时准备为你提供信息、解答问题或协助完成任务。\n\n如果你对我的技术原理、能力范围或训练方式感兴趣，我可以为你详细介绍。例如：\n\n- 我是基于大规模语言模型构建的，可以处理文本理解、生成、翻译、总结等任务。\n- 知识截止于2025年5月，只能提供在此之前的公开信息（实时信息需联网搜索）。\n- 不支持图像、视频识别（但可以读取上传文件中的文字）。\n- 对话内容匿名，不会保留个人隐私。\n\n你具体想了解哪个方面？比如：我是如何被训练出来的？我能帮你做什么？或者我有哪些局限性？都可以问我！😊', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 169, 'prompt_tokens': 146, 'total_tokens': 315, 'completion_tokens_details': None, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 146}, 'model_provider': 'deepseek', 'model_name': 'deepseek-v4-flash', 'system_fingerprint': 'fp_058df29938_prod0820_fp8_kvcache_20260402', 'id': '3883e6a4-ab7c-4620-94db-237352b1b3a6', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019dca1c-230a-7970-81dd-bf815275a841-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 146, 'output_tokens': 169, 'total_tokens': 315, 'input_token_details': {'cache_read': 0}, 'output_token_details': {}}), HumanMessage(content='珠穆朗玛峰有多高？', additional_kwargs={}, response_metadata={}, id='b18c3340-528c-497b-812a-f9e8b3edf8b2'), AIMessage(content='珠穆朗玛峰（Mount Everest）的最新官方高度为 **8848.86米**（约29,031.7英尺）。这一数据是由中国和尼泊尔两国联合测量团队于2020年12月8日共同公布的，它取代了此前传统的8848米（中国1975年数据）和8844.43米（中国2005年数据），是目前公认的最精确海拔。\n\n珠穆朗玛峰位于喜马拉雅山脉中尼边界，是世界第一高峰。如果你对它的攀登历史、地质特征或周边环境感兴趣，也可以继续问我！', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 121, 'prompt_tokens': 336, 'total_tokens': 457, 'completion_tokens_details': None, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 336}, 'model_provider': 'deepseek', 'model_name': 'deepseek-v4-flash', 'system_fingerprint': 'fp_058df29938_prod0820_fp8_kvcache_20260402', 'id': '43c82e20-8d56-4870-b285-57d121abd8af', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019dca1c-3664-74f3-9e14-aa8a87ea1646-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 336, 'output_tokens': 121, 'total_tokens': 457, 'input_token_details': {'cache_read': 0}, 'output_token_details': {}})]}
# Messages: 6
# Messages:{'messages': [HumanMessage(content='Here is a summary of the conversation to date:\n\n## SESSION INTENT\nSimple Q&A session covering basic arithmetic and day-of-week questions, now shifting to personal questions about the assistant\'s nature and capabilities.\n\n## SUMMARY\n- User asked "3+3" which equals 6.\n- User asked "If today is Wednesday, what is tomorrow?" — assistant confirmed Thursday.\n- User asked "how are you now?" — assistant responded that it functions well but has no feelings, then reciprocated the question.\n- User\'s latest message (in Chinese): "I want to know more about you/your situation" — this indicates a deepening interest in the assistant\'s identity, capabilities, or operational details.\n\n## ARTIFACTS\nNone\n\n## NEXT STEPS\nRespond to the user\'s request for more information about the assistant\'s nature, capabilities, or state of being. Consider explaining what kind of AI assistant they are speaking with.', additional_kwargs={'lc_source': 'summarization'}, response_metadata={}, id='0c90428d-2021-4d54-92d2-01e7a2bd1896'), AIMessage(content='感谢你的关心！作为一个AI助手，我没有情感、意识或生理状态，所以不存在“心情好”或“累”这类感受。但我一直处于待命状态，随时准备为你提供信息、解答问题或协助完成任务。\n\n如果你对我的技术原理、能力范围或训练方式感兴趣，我可以为你详细介绍。例如：\n\n- 我是基于大规模语言模型构建的，可以处理文本理解、生成、翻译、总结等任务。\n- 知识截止于2025年5月，只能提供在此之前的公开信息（实时信息需联网搜索）。\n- 不支持图像、视频识别（但可以读取上传文件中的文字）。\n- 对话内容匿名，不会保留个人隐私。\n\n你具体想了解哪个方面？比如：我是如何被训练出来的？我能帮你做什么？或者我有哪些局限性？都可以问我！😊', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 169, 'prompt_tokens': 146, 'total_tokens': 315, 'completion_tokens_details': None, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 146}, 'model_provider': 'deepseek', 'model_name': 'deepseek-v4-flash', 'system_fingerprint': 'fp_058df29938_prod0820_fp8_kvcache_20260402', 'id': '3883e6a4-ab7c-4620-94db-237352b1b3a6', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019dca1c-230a-7970-81dd-bf815275a841-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 146, 'output_tokens': 169, 'total_tokens': 315, 'input_token_details': {'cache_read': 0}, 'output_token_details': {}}), HumanMessage(content='珠穆朗玛峰有多高？', additional_kwargs={}, response_metadata={}, id='b18c3340-528c-497b-812a-f9e8b3edf8b2'), AIMessage(content='珠穆朗玛峰（Mount Everest）的最新官方高度为 **8848.86米**（约29,031.7英尺）。这一数据是由中国和尼泊尔两国联合测量团队于2020年12月8日共同公布的，它取代了此前传统的8848米（中国1975年数据）和8844.43米（中国2005年数据），是目前公认的最精确海拔。\n\n珠穆朗玛峰位于喜马拉雅山脉中尼边界，是世界第一高峰。如果你对它的攀登历史、地质特征或周边环境感兴趣，也可以继续问我！', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 121, 'prompt_tokens': 336, 'total_tokens': 457, 'completion_tokens_details': None, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 336}, 'model_provider': 'deepseek', 'model_name': 'deepseek-v4-flash', 'system_fingerprint': 'fp_058df29938_prod0820_fp8_kvcache_20260402', 'id': '43c82e20-8d56-4870-b285-57d121abd8af', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019dca1c-3664-74f3-9e14-aa8a87ea1646-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 336, 'output_tokens': 121, 'total_tokens': 457, 'input_token_details': {'cache_read': 0}, 'output_token_details': {}}), HumanMessage(content='中国面积有多大', additional_kwargs={}, response_metadata={}, id='888afa4d-d3b0-4f84-93d4-1040be971ec9'), AIMessage(content='中国的陆地领土面积约为 **960万平方公里**，位居世界第三（仅次于俄罗斯和加拿大）。这一数据通常指的是中华人民共和国实际管辖的陆地范围，不包括海域面积。\n\n如果加上 **领海（约37万平方公里）**，以及主张的 **管辖海域（包括专属经济区等，约300万平方公里）**，中国的总面积会更大。但日常提到“中国面积”时，一般以 **960万平方公里** 为主要参考标准。\n\n需要说明的是，中国官方公布的数据是 **约960万平方公里**，这是一个长期稳定的统计口径，用于国家地理概况。如果你需要更精确的测绘数据（例如基于最新遥感技术的具体数值），也可以进一步查询自然资源部等官方发布的信息。', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 147, 'prompt_tokens': 502, 'total_tokens': 649, 'completion_tokens_details': None, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens':  ...
# Messages: 6
